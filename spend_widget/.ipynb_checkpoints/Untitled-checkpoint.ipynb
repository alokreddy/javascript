# %%
import json
from pandas.io.json import json_normalize

# %%
with open('spend.json') as data_file:    
    data = json.load(data_file)  

data['data']['spendbydaterange']
# Out:
# {'spendbydaterange': [{'spend_date': '2018-04-02',
#    'supplier': 'Pinnacle',
#    'location': 'GAIG - Cincinnati - Dixie',
#    'job_category': 'Technology (IT)',
#    'regular_hours': '8.00',
#    'overtime_hours': '0.00',
#    'total_hours': '8.00',
#    'regular_billrate': '920.00',
#    'overtime_billrate': '0.00',
#    'total_billrate': '920.00'},
#   {'spend_date': '2018-04-02',
#    'supplier': 'Systems Insight',
#    'location': 'GAIG - Cincinnati - Tower',
#    'job_category': 'Technology (IT)',
#    'regular_hours': '8.00',
#    'overtime_hours': '0.00',
#    'total_hours': '8.00',
#    'regular_billrate': '504.00',
#    'overtime_billrate': '0.00',
#    'total_billrate': '504.00'},
#   {'spend_date': '2018-04-02',
#    'supplier': 'Click IT Staffing',
#    'location': 'GAIG - Cincinnati - Dixie',
#    'job_category': 'Technology (IT)',
#    'regular_hours': '8.00',
#    'overtime_hours': '0.00',
#    'total_hours': '8.00',
#    'regular_billrate': '672.00',
# ...
